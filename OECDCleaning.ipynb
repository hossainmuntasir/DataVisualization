# %%
import pandas as pd
df = pd.read_excel("../Test/Sample.xlsx")

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df.head()
# Out:
#    Year    Country   Females at birth   Females at age 40   Females at age 60  \
# 0  2010  Australia                 84                44.9                26.2
# 1  2010    Austria               83.5                44.3                25.7
# 2  2010    Belgium                 83                43.9                25.5
# 3  2010     Canada               83.5                44.6                  26
# 4  2010      Chile               81.7                43.1                24.7
#
#     Females at age 65   Females at age 80   Males at birth   Males at age 40  \
# 0                21.8                10.1             79.5                41
# 1                21.4                 9.8             77.8              39.3
# 2                21.3                 9.9             77.5                39
# 3                21.7                10.4             79.2              40.8
# 4                20.5                 9.9             75.9              38.2
#
# ...

# %%
import numpy as np

# %%
df.replace("..", np.nan)
# Out:
#      Year         Country    Females at birth    Females at age 40  \
# 0    2010       Australia                84.0                 44.9
# 1    2010         Austria                83.5                 44.3
# 2    2010         Belgium                83.0                 43.9
# 3    2010          Canada                83.5                 44.6
# 4    2010           Chile                81.7                 43.1
# ..    ...             ...                 ...                  ...
# 616  2022           India                68.9                  NaN
# 617  2022       Indonesia                69.7                  NaN
# 618  2022            Peru                74.7                  NaN
# 619  2022         Romania                79.3                  NaN
# 620  2022    South Africa                65.0                  NaN
#
#        Females at age 60    Females at age 65    Females at age 80  \
# 0                   26.2                 21.8                 10.1
# ...

# %%
df.value_counts()
# Out:
# Year  Country        Females at birth    Females at age 40    Females at age 60    Females at age 65    Females at age 80    Males at birth    Males at age 40    Males at age 60    Males at age 65    Males at age 80    Total population at birth
# 2010    Argentina  79.1                ..                   ..                   ..                   ..                   72.7              ..                 ..                 ..                 ..                 75.9                           1
# 2018  Hungary      79.6                40.4                 22.4                 18.5                 8.3                  72.7              33.9               17.5               14.6               7                  76.2                           1
# ...

# %%
df.to_json('data.json',orient='records')

# %%
df.to_csv("data.csv", index=False)

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_52052\3885826175.py in ?()
# ----> 1 df['Country'].year[2010]
#
# c:\Users\Hossain Muntasir\Anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'year'
